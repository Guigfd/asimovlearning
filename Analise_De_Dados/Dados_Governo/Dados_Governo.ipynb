# %% [markdown]
# # SETUP

# %%
import pandas as pd
from parso.pgen2.generator import DFAPlan

df_viagens = pd.read_csv('F:/Documentos/Python/Asimov/Analise_De_Dados/Dados_Governo/2023_Viagem.csv', sep=';',encoding='windows-1252', decimal=',') # sempre usar a barra assim /, essa barra aqui \ nao funciona!
# sempre verificar o tipo de enconding do arquivo!

pd.set_option('display.max_columns', None) # retira o limite de colunas mostradas

# %% [markdown]
# # Leitura dos dados

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 832888                           2023001618             Sem informaçã
# 832889                           2023001619             Sem informaçã
# 832890                           2023001628             Sem informaçã
# 832891                           2023001631             Sem informaçã
# 832892                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %% [markdown]
# # Operações com Colunas

# %%
df_viagens[["Valor diárias","Valor passagens"]] # acessar colunas com []
# Out:
#         Valor diárias  Valor passagens
# 0                0.00             0.00
# 1                0.00          7894.50
# 2                0.00             0.00
# 3            39565.70          7434.13
# 4             1013.96             0.00
# ...               ...              ...
# 832888         606.89          3331.29
# 832889        1089.00          1837.18
# 832890         734.13          4555.95
# 832891         319.28          3745.53
# 832892           0.00          2961.55
#
# [832893 rows x 2 columns]

# %%
df_viagens.info() # traz info da tabela
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 832893 entries, 0 to 832892
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  832893 non-null  int64
#  1   Número da Proposta (PCDP)            832893 non-null  str
#  2   Situação                             832893 non-null  str
#  3   Viagem Urgente                       832893 non-null  str
#  4   Justificativa Urgência Viagem        832791 non-null  str
#  5   Código do órgão superior             832893 non-null  int64
#  6   Nome do órgão superior               832893 non-null  str
#  7   Código órgão solicitante             832893 non-null  int64
#  8   Nome órgão solicitante               832893 non-null  str
#  9   CPF viajante                         749256 non-null  str
#  10  Nome                                 832893 non-null  str
# ...

# %%
df_viagens['Valor diárias']
# Out:
# 0             0.00
# 1             0.00
# 2             0.00
# 3         39565.70
# 4          1013.96
#             ...
# 832888      606.89
# 832889     1089.00
# 832890      734.13
# 832891      319.28
# 832892        0.00
# Name: Valor diárias, Length: 832893, dtype: float64

# %%
 # df_viagens['Valor devolução'] = df_viagens['Valor devolução'].str.replace(',', '.').astype(float)  # astype converte o tipo da variavel

# %%
df_viagens.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 832893 entries, 0 to 832892
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  832893 non-null  int64
#  1   Número da Proposta (PCDP)            832893 non-null  str
#  2   Situação                             832893 non-null  str
#  3   Viagem Urgente                       832893 non-null  str
#  4   Justificativa Urgência Viagem        832791 non-null  str
#  5   Código do órgão superior             832893 non-null  int64
#  6   Nome do órgão superior               832893 non-null  str
#  7   Código órgão solicitante             832893 non-null  int64
#  8   Nome órgão solicitante               832893 non-null  str
#  9   CPF viajante                         749256 non-null  str
#  10  Nome                                 832893 non-null  str
# ...

# %%
gastos = df_viagens['Valor diárias'] + df_viagens['Valor passagens'] + df_viagens['Valor outros gastos']

# %%
gastos
# Out:
# 0             0.00
# 1          7894.50
# 2             0.00
# 3         48095.18
# 4          1013.96
#             ...
# 832888     3938.18
# 832889     2926.18
# 832890     5290.08
# 832891     4464.81
# 832892     2961.55
# Length: 832893, dtype: float64

# %%
df_viagens['Despesas'] = gastos  # criando uma coluna nova

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 832888                           2023001618             Sem informaçã
# 832889                           2023001619             Sem informaçã
# 832890                           2023001628             Sem informaçã
# 832891                           2023001631             Sem informaçã
# 832892                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
df_viagens['Cargo'].value_counts() # frequencia / quantas vezes aparece na tabela
# Out:
# Cargo
# Informações protegidas por sigilo           118484
# PROFESSOR DO MAGISTERIO SUPERIOR             55010
# PROFESSOR ENS BASICO TECN TECNOLOGICO        37822
# CONTRATADO LEI 8745/93 - NI                  17787
# AUDITOR FISCAL FEDERAL AGROPECUARIO          16587
#                                              ...
# ESPEC GESTAO DE PROJETOS - 40H                   1
# ASSISTENTE DE CONTABILIDADE - NI                 1
# ASG - OPERADOR DE MAQUINA E EQUIPAMENTOS         1
# DIGITADOR I                                      1
# PROGRAMADOR DE COMPUTADOR                        1
# Name: count, Length: 824, dtype: int64

# %%
(df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporção de viagens').reset_index() # normalização de dados
# Out:
#                                         Cargo  Proporção de viagens
# 0           Informações protegidas por sigilo             23.350558
# 1            PROFESSOR DO MAGISTERIO SUPERIOR             10.841246
# 2       PROFESSOR ENS BASICO TECN TECNOLOGICO              7.453874
# 3                 CONTRATADO LEI 8745/93 - NI              3.505422
# 4         AUDITOR FISCAL FEDERAL AGROPECUARIO              3.268928
# ..                                        ...                   ...
# 819            ESPEC GESTAO DE PROJETOS - 40H              0.000197
# 820          ASSISTENTE DE CONTABILIDADE - NI              0.000197
# 821  ASG - OPERADOR DE MAQUINA E EQUIPAMENTOS              0.000197
# 822                               DIGITADOR I              0.000197
# 823                 PROGRAMADOR DE COMPUTADOR              0.000197
#
# [824 rows x 2 columns]
